# %%
import pandas as pd

# %%
data = pd.read_csv(r"data_climate.csv")

# %%
data
# Out:
#               date  temp_min  temp_max  temp_med  humedad_%  precip_mm  \
# 0       01-01-2010      21.4      30.2      27.1       82.0        9.0
# 1       02-01-2010      21.0      29.6      25.7       95.0       24.0
# 2       03-01-2010      20.2      26.8      24.5       98.0       63.0
# 3       04-01-2010      21.0      29.2      25.8       90.0        0.0
# 4       05-01-2010      21.2      30.0      26.7       90.0        2.0
# ...            ...       ...       ...       ...        ...        ...
# 589260  27-12-2020      25.2      31.2      29.2       74.0        0.0
# 589261  28-12-2020      25.3      31.6      28.1       78.0        NaN
# 589262  29-12-2020      24.6      32.3      28.4       81.0        NaN
# 589263  30-12-2020      25.2      32.6      28.4       80.0        0.0
# 589264  31-12-2020      24.3      32.0      26.7       86.0       26.6
#
#         horas_sol  max_viento_mxs  direcc_viento  med_viento_mxs  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 589265 entries, 0 to 589264
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   date                 589265 non-null  object
#  1   temp_min             565882 non-null  float64
#  2   temp_max             551529 non-null  float64
#  3   temp_med             544160 non-null  float64
#  4   humedad_%            541083 non-null  float64
#  5   precip_mm            463881 non-null  float64
#  6   horas_sol            545544 non-null  float64
#  7   max_viento_mxs       579051 non-null  float64
#  8   direcc_viento        576137 non-null  float64
#  9   med_viento_mxs       579138 non-null  float64
#  10  direcc_media_viento  575526 non-null  object
#  11  station_id           589265 non-null  int64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 53.9+ MB

# %%
data.describe()
# Out:
#             temp_min       temp_max       temp_med      humedad_%  \
# count  565882.000000  551529.000000  544160.000000  541083.000000
# mean       23.312111      31.528955      26.855475      82.489365
# std         2.280687       2.311659       1.939656      14.337669
# min         0.000000       0.000000       0.000000      24.000000
# 25%        23.000000      30.500000      26.200000      79.000000
# 50%        24.000000      31.800000      27.200000      83.000000
# 75%        25.000000      33.000000      28.000000      87.000000
# max       246.000000     334.000000     141.600000    7520.000000
#
#            precip_mm      horas_sol  max_viento_mxs  direcc_viento  \
# count  463881.000000  545544.000000   579051.000000  576137.000000
# mean        8.680760       5.083199        4.709601     188.488325
# std        17.928752       3.261586        2.612285     107.657452
# min        -1.000000       0.000000        0.000000       0.000000
# ...

# %%
data.temp_med.describe()
# Out:
# count    544160.000000
# mean         26.855475
# std           1.939656
# min           0.000000
# 25%          26.200000
# 50%          27.200000
# 75%          28.000000
# max         141.600000
# Name: temp_med, dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
temp_med = data['temp_med']
lluvia_mm = data['precip_mm']

# %%
temp = temp_med.values
mm = lluvia_mm.values
print(max)
print(min)
# Out:
# <built-in function max>
# <built-in function min>

# %%
fecha = data['date']
print(fecha.describe())
# Out:
# count         589265
# unique          4018
# top       20-12-2020
# freq             167
# Name: date, dtype: object

# %%
# array_fechas = fecha.value
# print(array_fechas)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax2 = ax1.twinx()

temp_med[:7].plot(color="red", ax=ax2, lw=2)
lluvia_mm[:7].plot(kind='bar', width=0.9,  ax=ax1)

ax2.set_ylim(0,  40)
ax1.yaxis.set_label_position("right")
ax1.yaxis.tick_right()
ax2.yaxis.set_label_position("left")
ax2.yaxis.tick_left()
ax1.spines['top'].set_visible(False)
ax2.spines['top'].set_visible(False)

fig.suptitle("Medellin")
ax2.set_ylabel("Temperatura Promedio (°C)")
ax1.set_ylabel("Precipitación Promedio (mm)")

plt.show()

# %% [markdown]
# # A PARTIR DE AQUÍ EMPIEZA LA MOVIDA DEL RANDOM FOREST

# %%
# Data Processing
import pandas as pd
import numpy as np

# Modelling
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint

# Tree Visualisation
from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz
